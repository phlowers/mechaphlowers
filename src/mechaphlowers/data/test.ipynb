# %%
import pandas as pd

pd.read_csv("/home/wangjer/Projects/mechaphlowers/src/mechaphlowers/data/section_import_from_proto_utf8.csv",decimal=",", sep=";", encoding="utf-8", dtype=str, index_col=0)
# Out:
#      nom suspension  alt_acc long_bras angle_ligne long_ch pds_ch surf_ch  \
# num
# 1     98       FAUX  1075,53         0       -19,1       0      0       0
# 2     99       VRAI  1071,86         0           0       2     65       0
# 3    100       VRAI  1065,51         0           0       2     65       0
# 4    101       VRAI  1068,57         0           5       2    130       0
# 5    102       VRAI  1006,16         0           0       2     65       0
# 6    103       VRAI  1076,51         0           0       2     65       0
# 7    104       VRAI  1081,92         0         1,4       2     65       0
# 8    105       VRAI  1090,16         0           0       2     65       0
# 9    106       VRAI  1111,39         0           0       2     65       0
# 10   107       VRAI  1143,57         0           0       2     65       0
# 11   108       VRAI  1122,55         0           0       2    130       0
# 12   109       VRAI   1265,1         0        -4,9       2    130       0
# ...
